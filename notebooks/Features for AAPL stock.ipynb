# %% [markdown]
# SENTIMENT DATA (JUST FROM 2021)

# %%
"""
import requests

# Replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=WIB4EPEUDA7KJFOG&sort=EARLIEST'

# Optional: Specify the time range
time_from = '20180612T2359'

# Append the time parameters to the URL
url += f'&time_from={time_from}'


# Optional: Specify the result limit
limit = 10
url += f'&limit={limit}'

r = requests.get(url)
data = r.json()

print(data)
"""

# %% [markdown]
# INFLATION (FOR ALL DATA WE REQUIRE)

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

data
# Out:
# {'name': 'Consumer Price Index for all Urban Consumers',
#  'interval': 'monthly',
#  'unit': 'index 1982-1984=100',
#  'data': [{'date': '2023-04-01', 'value': '303.363'},
#   {'date': '2023-03-01', 'value': '301.836'},
#   {'date': '2023-02-01', 'value': '300.840'},
#   {'date': '2023-01-01', 'value': '299.170'},
#   {'date': '2022-12-01', 'value': '296.797'},
#   {'date': '2022-11-01', 'value': '297.711'},
#   {'date': '2022-10-01', 'value': '298.012'},
#   {'date': '2022-09-01', 'value': '296.808'},
#   {'date': '2022-08-01', 'value': '296.171'},
#   {'date': '2022-07-01', 'value': '296.276'},
#   {'date': '2022-06-01', 'value': '296.311'},
#   {'date': '2022-05-01', 'value': '292.296'},
#   {'date': '2022-04-01', 'value': '289.109'},
#   {'date': '2022-03-01', 'value': '287.504'},
#   {'date': '2022-02-01', 'value': '283.716'},
#   {'date': '2022-01-01', 'value': '281.148'},
#   {'date': '2021-12-01', 'value': '278.802'},
#   {'date': '2021-11-01', 'value': '277.948'},
# ...

# %%
import pandas as pd
import json
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data_str = r.text

# Parse the string into a dictionary
data = json.loads(data_str)

df_CPI = pd.DataFrame(data['data'])
df_CPI.rename(columns={'date': 'Date'}, inplace=True)
df_CPI.rename(columns={'value': 'CPI'}, inplace=True)
df_CPI = df_CPI[df_CPI['Date'] >= '2018-06-12']
df_CPI = df_CPI.sort_values(by='Date',ascending=True)
df_CPI.reset_index(drop=True, inplace=True)
df_CPI
# Out:
#           Date      CPI
# 0   2018-07-01  252.006
# 1   2018-08-01  252.146
# 2   2018-09-01  252.439
# 3   2018-10-01  252.885
# 4   2018-11-01  252.038
# 5   2018-12-01  251.233
# 6   2019-01-01  251.712
# 7   2019-02-01  252.776
# 8   2019-03-01  254.202
# 9   2019-04-01  255.548
# 10  2019-05-01  256.092
# 11  2019-06-01  256.143
# 12  2019-07-01  256.571
# 13  2019-08-01  256.558
# 14  2019-09-01  256.759
# 15  2019-10-01  257.346
# 16  2019-11-01  257.208
# 17  2019-12-01  256.974
# 18  2020-01-01  257.971
# 19  2020-02-01  258.678
# 20  2020-03-01  258.115
# 21  2020-04-01  256.389
# 22  2020-05-01  256.394
# 23  2020-06-01  257.797
# 24  2020-07-01  259.101
# 25  2020-08-01  259.918
# 26  2020-09-01  260.280
# 27  2020-10-01  260.388
# 28  2020-11-01  260.229
# 29  2020-12-01  260.474
# 30  2021-01-01  261.582
# 31  2021-02-01  263.014
# 32  2021-03-01  264.877
# 33  2021-04-01  267.054
# 34  2021-05-01  269.195
# 35  2021-06-01  271.696
# 36  2021-07-01  273.003
# ...

# %% [markdown]
# FEDERAL FUNDS (INTEREST) RATE (FOR ALL DATA WE REQUIRE)

# %%
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=daily&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

data
# Out:
# {'name': 'Effective Federal Funds Rate',
#  'interval': 'daily',
#  'unit': 'percent',
#  'data': [{'date': '2023-06-07', 'value': '5.08'},
#   {'date': '2023-06-06', 'value': '5.08'},
#   {'date': '2023-06-05', 'value': '5.08'},
#   {'date': '2023-06-04', 'value': '5.08'},
#   {'date': '2023-06-03', 'value': '5.08'},
#   {'date': '2023-06-02', 'value': '5.08'},
#   {'date': '2023-06-01', 'value': '5.08'},
#   {'date': '2023-05-31', 'value': '5.08'},
#   {'date': '2023-05-30', 'value': '5.08'},
#   {'date': '2023-05-29', 'value': '5.08'},
#   {'date': '2023-05-28', 'value': '5.08'},
#   {'date': '2023-05-27', 'value': '5.08'},
#   {'date': '2023-05-26', 'value': '5.08'},
#   {'date': '2023-05-25', 'value': '5.08'},
#   {'date': '2023-05-24', 'value': '5.08'},
#   {'date': '2023-05-23', 'value': '5.08'},
#   {'date': '2023-05-22', 'value': '5.08'},
#   {'date': '2023-05-21', 'value': '5.08'},
#   {'date': '2023-05-20', 'value': '5.08'},
#   {'date': '2023-05-19', 'value': '5.08'},
# ...

# %%
import pandas as pd
import json
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=FEDERAL_FUNDS_RATE&interval=daily&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data_str = r.text

# Parse the string into a dictionary
data = json.loads(data_str)

df_interest = pd.DataFrame(data['data'])
df_interest.rename(columns={'date': 'Date'}, inplace=True)
df_interest.rename(columns={'value': 'Interest'}, inplace=True)
# Convert 'Date' column to datetime format
df_interest['Date'] = pd.to_datetime(df_interest['Date'])

# Filter the DataFrame
df_interest = df_interest[df_interest['Date'] >= '2018-06-12']
df_interest = df_interest.sort_values(by='Date',ascending=True)
# Convert 'Interest' column to numeric
df_interest['Interest'] = pd.to_numeric(df_interest['Interest'], errors='coerce')
df_interest['Interest'] = df_interest['Interest'] / 100
df_interest.reset_index(drop=True, inplace=True)
df_interest
# Out:
#            Date  Interest
# 0    2018-06-12    0.0170
# 1    2018-06-13    0.0170
# 2    2018-06-14    0.0190
# 3    2018-06-15    0.0190
# 4    2018-06-16    0.0190
# ...         ...       ...
# 1817 2023-06-03    0.0508
# 1818 2023-06-04    0.0508
# 1819 2023-06-05    0.0508
# 1820 2023-06-06    0.0508
# 1821 2023-06-07    0.0508
#
# [1822 rows x 2 columns]

# %%
import pandas as pd

# Convert the 'Date' column in df_interest to datetime data type
df_interest['Date'] = pd.to_datetime(df_interest['Date'])
# Convert the 'Date' column in df_CPI to datetime data type
df_CPI['Date'] = pd.to_datetime(df_CPI['Date'])

# Perform the merge
df_interest_cpi = df_interest.merge(df_CPI, on='Date', how='left')
df_interest_cpi
# Out:
#            Date  Interest  CPI
# 0    2018-06-12    0.0170  NaN
# 1    2018-06-13    0.0170  NaN
# 2    2018-06-14    0.0190  NaN
# 3    2018-06-15    0.0190  NaN
# 4    2018-06-16    0.0190  NaN
# ...         ...       ...  ...
# 1817 2023-06-03    0.0508  NaN
# 1818 2023-06-04    0.0508  NaN
# 1819 2023-06-05    0.0508  NaN
# 1820 2023-06-06    0.0508  NaN
# 1821 2023-06-07    0.0508  NaN
#
# [1822 rows x 3 columns]

# %% [markdown]
# COMPANY OVERVIEW (JUST CURRENT YEAR)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=OVERVIEW&symbol=AAPL&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)"""

# %% [markdown]
# INCOME STATEMENT (JUST FROM 2018)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=AAPL&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)
"""

# %% [markdown]
# BALANCE SHEET (JUST FROM 2018)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=AAPL&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)
"""

# %% [markdown]
# CASH FLOW (JUST FROM 2018)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=CASH_FLOW&symbol=AAPL&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)
"""

# %% [markdown]
# EARNINGS (FOR ALL DATA WE REQUIRE)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=AAPL&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)
"""

# %% [markdown]
# DURABLE GOODS ORDERS (FOR ALL DATA WE REQUIRE)

# %%
"""
import requests

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=DURABLES&apikey=WIB4EPEUDA7KJFOG'
r = requests.get(url)
data = r.json()

print(data)
"""

# %%
import pandas as pd

# Specify the file path of the CSV file
csv_file_path = '/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/AAPL_Financials.csv'

# Read the CSV file using pandas
aapl_finances_df = pd.read_csv(csv_file_path)

# Print the DataFrame
aapl_finances_df
# Out:
#          Dates Apple Quarterly Revenue\n(Millions of US $)  \
# 0   2023-03-31                                     $94,836
# 1   2022-12-31                                    $117,154
# 2   2022-09-30                                     $90,146
# 3   2022-06-30                                     $82,959
# 4   2022-03-31                                     $97,278
# 5   2021-12-31                                    $123,945
# 6   2021-09-30                                     $83,360
# 7   2021-06-30                                     $81,434
# 8   2021-03-31                                     $89,584
# 9   2020-12-31                                    $111,439
# 10  2020-09-30                                     $64,698
# 11  2020-06-30                                     $59,685
# 12  2020-03-31                                     $58,313
# 13  2019-12-31                                     $91,819
# 14  2019-09-30                                     $64,040
# ...

# %%
#12th junen 2018
aapl_finances_df = aapl_finances_df.drop(aapl_finances_df[aapl_finances_df.index > 19].index)
aapl_finances_df
# Out:
#          Dates Apple Quarterly Revenue\n(Millions of US $)  \
# 0   2023-03-31                                     $94,836
# 1   2022-12-31                                    $117,154
# 2   2022-09-30                                     $90,146
# 3   2022-06-30                                     $82,959
# 4   2022-03-31                                     $97,278
# 5   2021-12-31                                    $123,945
# 6   2021-09-30                                     $83,360
# 7   2021-06-30                                     $81,434
# 8   2021-03-31                                     $89,584
# 9   2020-12-31                                    $111,439
# 10  2020-09-30                                     $64,698
# 11  2020-06-30                                     $59,685
# 12  2020-03-31                                     $58,313
# 13  2019-12-31                                     $91,819
# 14  2019-09-30                                     $64,040
# ...

# %%
aapl_finances_df['Apple Quarterly Revenue\n(Millions of US $)'] = aapl_finances_df['Apple Quarterly Revenue\n(Millions of US $)'].str.replace('$', '')
aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'] = aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'].str.replace('$', '')
aapl_finances_df['Apple Quarterly EPS'] = aapl_finances_df['Apple Quarterly EPS'].str.replace('$','')
aapl_finances_df['Apple Quarterly Operating Margin'] = aapl_finances_df['Apple Quarterly Operating Margin'].str.replace('%','')
# Convert the column to numeric type
aapl_finances_df['Apple Quarterly Operating Margin'] = pd.to_numeric(aapl_finances_df['Apple Quarterly Operating Margin'], errors='coerce')
aapl_finances_df['Apple Quarterly Operating Margin'] = aapl_finances_df['Apple Quarterly Operating Margin'] / 100
aapl_finances_df
# Out:
#          Dates Apple Quarterly Revenue\n(Millions of US $)  \
# 0   2023-03-31                                      94,836
# 1   2022-12-31                                     117,154
# 2   2022-09-30                                      90,146
# 3   2022-06-30                                      82,959
# 4   2022-03-31                                      97,278
# 5   2021-12-31                                     123,945
# 6   2021-09-30                                      83,360
# 7   2021-06-30                                      81,434
# 8   2021-03-31                                      89,584
# 9   2020-12-31                                     111,439
# 10  2020-09-30                                      64,698
# 11  2020-06-30                                      59,685
# 12  2020-03-31                                      58,313
# 13  2019-12-31                                      91,819
# 14  2019-09-30                                      64,040
# ...

# %%
aapl_finances_df['Apple Quarterly Revenue\n(Millions of US $)'] = aapl_finances_df['Apple Quarterly Revenue\n(Millions of US $)'].str.replace(',', '.')
aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'] = aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'].str.replace(',', '.')
aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'] = aapl_finances_df['Apple Quarterly Net Income\n(Millions of US $)'].str.replace(',', '.')
aapl_finances_df=aapl_finances_df.sort_values(by='Dates',ascending=True)
aapl_finances_df.reset_index(drop=True, inplace=True)
aapl_finances_df.rename(columns={'Dates': 'Date'}, inplace=True)
aapl_finances_df
# Out:
#           Date Apple Quarterly Revenue\n(Millions of US $)  \
# 0   2018-06-30                                      53.265
# 1   2018-09-30                                      62.900
# 2   2018-12-31                                      84.310
# 3   2019-03-31                                      58.015
# 4   2019-06-30                                      53.809
# 5   2019-09-30                                      64.040
# 6   2019-12-31                                      91.819
# 7   2020-03-31                                      58.313
# 8   2020-06-30                                      59.685
# 9   2020-09-30                                      64.698
# 10  2020-12-31                                     111.439
# 11  2021-03-31                                      89.584
# 12  2021-06-30                                      81.434
# 13  2021-09-30                                      83.360
# 14  2021-12-31                                     123.945
# ...

# %%
aapl_finances_df.to_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/AAPL_financials_df.csv', index=False)

# %%
aapl_finances_df = pd.read_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/AAPL_financials_df_2.csv')
aapl_finances_df
# Out:
#           Date  Apple Quarterly Revenue\n(Millions of US $)  \
# 0   2018-06-29                                       53.265
# 1   2018-09-28                                       62.900
# 2   2018-12-31                                       84.310
# 3   2019-03-29                                       58.015
# 4   2019-06-28                                       53.809
# 5   2019-09-30                                       64.040
# 6   2019-12-31                                       91.819
# 7   2020-03-31                                       58.313
# 8   2020-06-30                                       59.685
# 9   2020-09-30                                       64.698
# 10  2020-12-31                                      111.439
# 11  2021-03-31                                       89.584
# 12  2021-06-30                                       81.434
# 13  2021-09-30                                       83.360
# 14  2021-12-31                                      123.945
# ...

# %%
df_EPS=pd.DataFrame(aapl_finances_df[['Date', 'Apple Quarterly EPS']])
df_EPS
# Out:
#           Date  Apple Quarterly EPS
# 0   2018-06-29                 0.59
# 1   2018-09-28                 0.74
# 2   2018-12-31                 1.05
# 3   2019-03-29                 0.62
# 4   2019-06-28                 0.55
# 5   2019-09-30                 0.77
# 6   2019-12-31                 1.25
# 7   2020-03-31                 0.64
# 8   2020-06-30                 0.65
# 9   2020-09-30                 0.74
# 10  2020-12-31                 1.68
# 11  2021-03-31                 1.40
# 12  2021-06-30                 1.30
# 13  2021-09-30                 1.23
# 14  2021-12-31                 2.10
# 15  2022-03-31                 1.52
# 16  2022-06-30                 1.20
# 17  2022-09-30                 1.29
# 18  2022-12-30                 1.88
# 19  2023-03-31                 1.52

# %%
import yfinance as yf

# %%
data= yf.download("AAPL","2018-06-12","2023-06-07")
close_df= pd.DataFrame(data['Close'])
close_df = close_df.sort_values(by='Date',ascending=True)
close_df.reset_index(drop=False, inplace=True)
close_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date       Close
# 0    2018-06-12   48.070000
# 1    2018-06-13   47.674999
# 2    2018-06-14   47.700001
# 3    2018-06-15   47.209999
# 4    2018-06-18   47.185001
# ...         ...         ...
# 1250 2023-05-31  177.250000
# 1251 2023-06-01  180.089996
# 1252 2023-06-02  180.949997
# 1253 2023-06-05  179.580002
# 1254 2023-06-06  179.210007
#
# [1255 rows x 2 columns]

# %%
# Convert "Date" column to datetime in df_new
close_df['Date'] = pd.to_datetime(close_df['Date'])

# Convert "Date" column to datetime in df_EPS
df_EPS['Date'] = pd.to_datetime(df_EPS['Date'])

# Merge df_EPS onto df_new using left merge
merged_financial_df = close_df.merge(df_EPS, on='Date', how='left')

merged_financial_df
# Out:
#            Date       Close  Apple Quarterly EPS
# 0    2018-06-12   48.070000                  NaN
# 1    2018-06-13   47.674999                  NaN
# 2    2018-06-14   47.700001                  NaN
# 3    2018-06-15   47.209999                  NaN
# 4    2018-06-18   47.185001                  NaN
# ...         ...         ...                  ...
# 1250 2023-05-31  177.250000                  NaN
# 1251 2023-06-01  180.089996                  NaN
# 1252 2023-06-02  180.949997                  NaN
# 1253 2023-06-05  179.580002                  NaN
# 1254 2023-06-06  179.210007                  NaN
#
# [1255 rows x 3 columns]

# %%
merged_financial_df.to_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/output.csv', index=False)
merged_financial_df = pd.read_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/output_2.csv')

# %%
merged_financial_df
# Out:
#             Date       Close   EPS         PE
# 0            NaN         NaN  0.52        NaN
# 1            NaN         NaN  0.97        NaN
# 2            NaN         NaN  0.68        NaN
# 3     2018-06-12   48.070000  2.98   9.333981
# 4     2018-06-13   47.674999  2.98   9.257281
# ...          ...         ...   ...        ...
# 1253  2023-05-31  177.250000  1.52  30.093379
# 1254  2023-06-01  180.089996  1.52  30.575551
# 1255  2023-06-02  180.949997  1.52  30.721561
# 1256  2023-06-05  179.580002  1.52  30.488965
# 1257  2023-06-06  179.210007  1.52  30.426147
#
# [1258 rows x 4 columns]

# %%
merged_financial_df=merged_financial_df.drop(merged_financial_df[merged_financial_df.index < 3].index)
merged_financial_df.reset_index(drop=True, inplace=True)
merged_financial_df
# Out:
#             Date       Close   EPS         PE
# 0     2018-06-12   48.070000  2.98   9.333981
# 1     2018-06-13   47.674999  2.98   9.257281
# 2     2018-06-14   47.700001  2.98   9.262136
# 3     2018-06-15   47.209999  2.98   9.166990
# 4     2018-06-18   47.185001  2.98   9.162136
# ...          ...         ...   ...        ...
# 1250  2023-05-31  177.250000  1.52  30.093379
# 1251  2023-06-01  180.089996  1.52  30.575551
# 1252  2023-06-02  180.949997  1.52  30.721561
# 1253  2023-06-05  179.580002  1.52  30.488965
# 1254  2023-06-06  179.210007  1.52  30.426147
#
# [1255 rows x 4 columns]

# %%
merged_financial_df.drop('EPS', axis=1, inplace=True)
merged_financial_df
# Out:
#             Date       Close         PE
# 0     2018-06-12   48.070000   9.333981
# 1     2018-06-13   47.674999   9.257281
# 2     2018-06-14   47.700001   9.262136
# 3     2018-06-15   47.209999   9.166990
# 4     2018-06-18   47.185001   9.162136
# ...          ...         ...        ...
# 1250  2023-05-31  177.250000  30.093379
# 1251  2023-06-01  180.089996  30.575551
# 1252  2023-06-02  180.949997  30.721561
# 1253  2023-06-05  179.580002  30.488965
# 1254  2023-06-06  179.210007  30.426147
#
# [1255 rows x 3 columns]

# %%
merged_financial_df = merged_financial_df.merge(aapl_finances_df, on='Date', how='left')

# %%
merged_financial_df
# Out:
#             Date       Close         PE  \
# 0     2018-06-12   48.070000   9.333981
# 1     2018-06-13   47.674999   9.257281
# 2     2018-06-14   47.700001   9.262136
# 3     2018-06-15   47.209999   9.166990
# 4     2018-06-18   47.185001   9.162136
# ...          ...         ...        ...
# 1250  2023-05-31  177.250000  30.093379
# 1251  2023-06-01  180.089996  30.575551
# 1252  2023-06-02  180.949997  30.721561
# 1253  2023-06-05  179.580002  30.488965
# 1254  2023-06-06  179.210007  30.426147
#
#       Apple Quarterly Revenue\n(Millions of US $)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1250                                          NaN
# 1251                                          NaN
# ...

# %%
df_interest_cpi['Date'] = pd.to_datetime(df_interest_cpi['Date'])
merged_financial_df['Date'] = pd.to_datetime(merged_financial_df['Date'])


df_final = df_interest_cpi.merge(merged_financial_df, on='Date', how='left')
df_final
# Out:
#            Date  Interest  CPI       Close         PE  \
# 0    2018-06-12    0.0170  NaN   48.070000   9.333981
# 1    2018-06-13    0.0170  NaN   47.674999   9.257281
# 2    2018-06-14    0.0190  NaN   47.700001   9.262136
# 3    2018-06-15    0.0190  NaN   47.209999   9.166990
# 4    2018-06-16    0.0190  NaN         NaN        NaN
# ...         ...       ...  ...         ...        ...
# 1817 2023-06-03    0.0508  NaN         NaN        NaN
# 1818 2023-06-04    0.0508  NaN         NaN        NaN
# 1819 2023-06-05    0.0508  NaN  179.580002  30.488965
# 1820 2023-06-06    0.0508  NaN  179.210007  30.426147
# 1821 2023-06-07    0.0508  NaN         NaN        NaN
#
#       Apple Quarterly Revenue\n(Millions of US $)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...

# %%
df_final.to_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/df_final.csv', index=False)

# %%
df_final = pd.read_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/df_final_2.csv')
df_final
# Out:
#             Date  Interest      CPI       Close         PE  \
# 0     2018-06-12    0.0170  251.989   48.070000   9.333981
# 1     2018-06-13    0.0170  251.989   47.674999   9.257281
# 2     2018-06-14    0.0190  251.989   47.700001   9.262136
# 3     2018-06-15    0.0190  251.989   47.209999   9.166990
# 4     2018-06-16    0.0190  251.989         NaN        NaN
# ...          ...       ...      ...         ...        ...
# 1817  2023-06-03    0.0508  303.363         NaN        NaN
# 1818  2023-06-04    0.0508  303.363         NaN        NaN
# 1819  2023-06-05    0.0508  303.363  179.580002  30.488965
# 1820  2023-06-06    0.0508  303.363  179.210007  30.426147
# 1821  2023-06-07    0.0508  303.363         NaN        NaN
#
#       Apple Quarterly Revenue\n(Millions of US $)  \
# 0                                          61.137
# 1                                          61.137
# 2                                          61.137
# 3                                          61.137
# ...

# %%
df_final.dropna(subset=['Close', 'PE'], how='all', inplace=True)

# %%
df_final
# Out:
#             Date  Interest      CPI       Close         PE  \
# 0     2018-06-12    0.0170  251.989   48.070000   9.333981
# 1     2018-06-13    0.0170  251.989   47.674999   9.257281
# 2     2018-06-14    0.0190  251.989   47.700001   9.262136
# 3     2018-06-15    0.0190  251.989   47.209999   9.166990
# 6     2018-06-18    0.0190  251.989   47.185001   9.162136
# ...          ...       ...      ...         ...        ...
# 1814  2023-05-31    0.0508  303.363  177.250000  30.093379
# 1815  2023-06-01    0.0508  303.363  180.089996  30.575551
# 1816  2023-06-02    0.0508  303.363  180.949997  30.721561
# 1819  2023-06-05    0.0508  303.363  179.580002  30.488965
# 1820  2023-06-06    0.0508  303.363  179.210007  30.426147
#
#       Apple Quarterly Revenue\n(Millions of US $)  \
# 0                                          61.137
# 1                                          61.137
# 2                                          61.137
# 3                                          61.137
# ...

# %%
df_final.to_csv('/Users/emanuelbayat/code/Fetyukovitch/SMA/raw_data/df_aapl_final.csv', index=False)

# %%
2018-02-09 2018-03-27 2018-07-12 2018-09-21 2018-10-26 2018-10-30 2018-11-07 2019-03-18 2019-03-19 2019-03-20 2019-05-21 2019-05-28 2019-07-09 2019-08-20 2019-09-20 2019-09-25 2019-10-30 2019-11-13 2019-12-10 2020-03-18 2020-04-24 2020-05-04 2020-08-04 2020-09-18 2020-10-23 2020-11-13 2020-11-16 2020-11-17 2020-12-15 2021-04-30 2021-05-21 2021-07-13 2021-09-24 2021-10-08 2021-10-26 2021-11-01 2022-03-18 2022-06-24 2022-07-15 2022-09-16 2022-09-23 2022-10-07 2022-10-26 2022-11-04 2023-01-24 2023-01-24 2023-01-24 2023-02-03

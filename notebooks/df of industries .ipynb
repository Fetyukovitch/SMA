# %%
"""import requests

for symbol in symbols_list:
    url = f"https://query1.finance.yahoo.com/v10/finance/quoteSummary/{symbol}?modules=assetProfile"
    print(url)
    response = requests.get(url)
    print(response)
    data = response.content
    
    industry = data["quoteSummary"]["result"][0]["assetProfile"].get("industry", "N/A")
    print("Symbol:", symbol)
    print("Industry:", industry)
    """
# Out:
# 'import requests\n\nfor symbol in symbols_list:\n    url = f"https://query1.finance.yahoo.com/v10/finance/quoteSummary/{symbol}?modules=assetProfile"\n    print(url)\n    response = requests.get(url)\n    print(response)\n    data = response.content\n    \n    industry = data["quoteSummary"]["result"][0]["assetProfile"].get("industry", "N/A")\n    print("Symbol:", symbol)\n    print("Industry:", industry)\n    '

# %%
"""
offset = 0
limit = None
period = '10y'
"""
# Out:
# "\noffset = 0\nlimit = None\nperiod = '10y'\n"

# %%
"""
import pandas as pd

data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('total number of symbols traded = {}'.format(len(symbols)))
"""
# Out:
# '\nimport pandas as pd\n\ndata = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep=\'|\')\ndata_clean = data[data[\'Test Issue\'] == \'N\']\nsymbols = data_clean[\'NASDAQ Symbol\'].tolist()\nprint(\'total number of symbols traded = {}\'.format(len(symbols)))\n'

# %%
"""
symbols_list = data_clean["Symbol"].to_list()
"""
# Out:
# '\nsymbols_list = data_clean["Symbol"].to_list()\n'

# %%
"""
symbols_list
"""
# Out:
# '\nsymbols_list\n'

# %%
"""
offset = 0
limit = None
period = '10y'
import pandas as pd


data = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep='|')
data_clean = data[data['Test Issue'] == 'N']
symbols = data_clean['NASDAQ Symbol'].tolist()
print('total number of symbols traded = {}'.format(len(symbols)))

symbols_list = data_clean["Symbol"].to_list()

industry_dict = dict()

import yfinance as yf

for symbol in symbols_list:
    try:
        ticker = yf.Ticker(symbol)
        industry = ticker.info.get("industry")
        if industry is not None:
            industry_dict[symbol] = industry
            continue
    except Exception as e:
        continue
"""
# Out:
# '\noffset = 0\nlimit = None\nperiod = \'10y\'\nimport pandas as pd\n\n\ndata = pd.read_csv("http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt", sep=\'|\')\ndata_clean = data[data[\'Test Issue\'] == \'N\']\nsymbols = data_clean[\'NASDAQ Symbol\'].tolist()\nprint(\'total number of symbols traded = {}\'.format(len(symbols)))\n\nsymbols_list = data_clean["Symbol"].to_list()\n\nindustry_dict = dict()\n\nimport yfinance as yf\n\nfor symbol in symbols_list:\n    try:\n        ticker = yf.Ticker(symbol)\n        industry = ticker.info.get("industry")\n        if industry is not None:\n            industry_dict[symbol] = industry\n            continue\n    except Exception as e:\n        continue\n'

# %%
"""

import pickle

with open("industry.pkl", "wb") as f:
    pickle.dump({"industries": industry_dict}, f)
    
    """
# Out:
# '\n\nimport pickle\n\nwith open("industry.pkl", "wb") as f:\n    pickle.dump({"industries": industry_dict}, f)\n    \n    '

# %%
with open("industry.pkl", "rb") as f:
    industries = pickle.load(f)

# %%
industries
# Out:
# {'industries': {'A': 'Diagnostics & Research',
#   'AA': 'Aluminum',
#   'AAC': 'Shell Companies',
#   'AACG': 'Education & Training Services',
#   'AACI': 'Shell Companies',
#   'AACIU': 'Shell Companies',
#   'AADI': 'Biotechnology',
#   'AAIC': 'REIT—Mortgage',
#   'AAL': 'Airlines',
#   'AAMC': 'Mortgage Finance',
#   'AAME': 'Insurance—Life',
#   'AAN': 'Rental & Leasing Services',
#   'AAOI': 'Communication Equipment',
#   'AAON': 'Building Products & Equipment',
#   'AAP': 'Specialty Retail',
#   'AAPL': 'Consumer Electronics',
#   'AAT': 'REIT—Diversified',
#   'AAU': 'Gold',
#   'AB': 'Asset Management',
#   'ABBV': 'Drug Manufacturers—General',
#   'ABC': 'Medical Distribution',
#   'ABCB': 'Banks—Regional',
#   'ABCL': 'Biotechnology',
#   'ABCM': 'Biotechnology',
#   'ABEO': 'Biotechnology',
#   'ABEV': 'Beverages—Brewers',
#   'ABG': 'Auto & Truck Dealerships',
#   'ABIO': 'Biotechnology',
#   'ABM': 'Specialty Business Services',
#   'ABNB': 'Travel Services',
#   'ABOS': 'Biotechnology',
#   'ABR': 'REIT—Mortgage',
#   'ABSI': 'Biotechnology',
#   'ABST': 'Software—Application',
#   'ABT': 'Medical Devices',
#   'ABUS': 'Biotechnology',
#   'ABVC': 'Biotechnology',
#   'AC': 'Asset Management',
#   'ACA': 'Engineering & Construction',
#   'ACAB': 'Shell Companies',
#   'ACABU': 'Shell Companies',
#   'ACAC': 'Shell Companies',
#   'ACACU': 'Shell Companies',
#   'ACAD': 'Biotechnology',
#   'ACAH': 'Shell Companies',
#   'ACAHU': 'Shell Companies',
#   'ACAQ': 'Shell Companies',
#   'ACAX': 'Shell Companies',
#   'ACAXU': 'Shell Companies',
#   'ACB': 'Drug Manufacturers—Specialty & Generic',
#   'ACBA': 'Shell Companies',
#   'ACBAU': 'Shell Companies',
#   'ACCD': 'Health Information Services',
#   'ACCO': 'Business Equipment & Supplies',
#   'ACDC': 'Oil & Gas Equipment & Services',
#   'ACEL': 'Gambling',
#   'ACER': 'Biotechnology',
#   'ACET': 'Biotechnology',
#   'ACGL': 'Insurance—Diversified',
#   'ACGLN': 'Insurance—Diversified',
#   'ACGLO': 'Insurance—Diversified',
#   'ACGN': 'Biotechnology',
#   'ACHC': 'Medical Care Facilities',
#   'ACHL': 'Biotechnology',
#   'ACHR': 'Aerospace & Defense',
#   'ACHV': 'Biotechnology',
#   'ACI': 'Grocery Stores',
#   'ACIU': 'Biotechnology',
#   'ACIW': 'Software—Infrastructure',
#   'ACLS': 'Semiconductor Equipment & Materials',
#   'ACLX': 'Biotechnology',
#   'ACM': 'Engineering & Construction',
#   'ACMR': 'Semiconductor Equipment & Materials',
#   'ACN': 'Information Technology Services',
#   'ACNB': 'Banks—Regional',
#   'ACNT': 'Steel',
#   'ACON': 'Health Information Services',
#   'ACOR': 'Drug Manufacturers—Specialty & Generic',
#   'ACP': 'Asset Management',
#   'ACR': 'REIT—Mortgage',
#   'ACRE': 'REIT—Mortgage',
#   'ACRO': 'Shell Companies',
#   'ACRS': 'Diagnostics & Research',
#   'ACRV': 'Biotechnology',
#   'ACRX': 'Drug Manufacturers—Specialty & Generic',
#   'ACST': 'Biotechnology',
#   'ACT': 'Insurance—Specialty',
#   'ACTG': 'Business Equipment & Supplies',
#   'ACU': 'Household & Personal Products',
#   'ACV': 'Asset Management',
#   'ACVA': 'Auto & Truck Dealerships',
#   'ACXP': 'Biotechnology',
#   'ADAG': 'Biotechnology',
#   'ADAP': 'Biotechnology',
#   'ADBE': 'Software—Infrastructure',
#   'ADC': 'REIT—Retail',
#   'ADCT': 'Biotechnology',
#   'ADD': 'Entertainment',
#   'ADEA': 'Software—Application',
#   'ADER': 'Shell Companies',
#   'ADERU': 'Shell Companies',
#   'ADES': 'Pollution & Treatment Controls',
#   'ADEX': 'Shell Companies',
#   'ADI': 'Semiconductors',
#   'ADIL': 'Biotechnology',
#   'ADM': 'Farm Products',
#   'ADMA': 'Biotechnology',
#   'ADMP': 'Drug Manufacturers—Specialty & Generic',
#   'ADN': 'Utilities—Renewable',
#   'ADNT': 'Auto Parts',
#   'ADOC': 'Shell Companies',
#   'ADP': 'Staffing & Employment Services',
#   'ADPT': 'Biotechnology',
#   'ADRT': 'Shell Companies',
#   'ADSE': 'Electrical Equipment & Parts',
#   'ADSK': 'Software—Application',
#   'ADT': 'Security & Protection Services',
#   'ADTH': 'Advertising Agencies',
#   'ADTN': 'Communication Equipment',
#   'ADTX': 'Biotechnology',
#   'ADUS': 'Medical Care Facilities',
#   'ADV': 'Advertising Agencies',
#   'ADVM': 'Biotechnology',
#   'ADX': 'Asset Management',
#   'ADXN': 'Biotechnology',
#   'AE': 'Oil & Gas Refining & Marketing',
#   'AEAE': 'Shell Companies',
#   'AEAEU': 'Shell Companies',
#   'AEE': 'Utilities—Regulated Electric',
#   'AEF': 'Asset Management',
#   'AEG': 'Insurance—Diversified',
#   'AEHL': 'Building Products & Equipment',
#   'AEHR': 'Semiconductor Equipment & Materials',
#   'AEI': 'Real Estate—Development',
#   'AEIS': 'Electrical Equipment & Parts',
#   'AEL': 'Insurance—Life',
#   'AEM': 'Gold',
#   'AEMD': 'Medical Devices',
#   'AENZ': 'Engineering & Construction',
#   'AEO': 'Apparel Retail',
#   'AEP': 'Utilities—Regulated Electric',
#   'AEPPZ': 'Utilities—Regulated Electric',
#   'AER': 'Rental & Leasing Services',
#   'AES': 'Utilities—Diversified',
#   'AESC': 'Utilities—Diversified',
#   'AESI': 'Oil & Gas Equipment & Services',
#   'AEVA': 'Auto Parts',
#   'AEY': 'Electronics & Computer Distribution',
#   'AEYE': 'Software—Application',
#   'AEZS': 'Biotechnology',
#   'AFAR': 'Shell Companies',
#   'AFARU': 'Shell Companies',
#   'AFB': 'Asset Management',
#   'AFBI': 'Banks—Regional',
#   'AFCG': 'REIT—Specialty',
#   'AFG': 'Insurance—Property & Casualty',
#   'AFIB': 'Medical Devices',
#   'AFL': 'Insurance—Life',
#   'AFMD': 'Biotechnology',
#   'AFRI': 'Farm Products',
#   'AFRM': 'Software—Infrastructure',
#   'AFT': 'Asset Management',
#   'AFTR': 'Shell Companies',
#   'AFYA': 'Education & Training Services',
#   'AG': 'Silver',
#   'AGAC': 'Shell Companies',
#   'AGAE': 'Entertainment',
#   'AGBA': 'Capital Markets',
#   'AGCO': 'Farm & Heavy Construction Machinery',
#   'AGE': 'Biotechnology',
#   'AGEN': 'Biotechnology',
#   'AGFY': 'Engineering & Construction',
#   'AGI': 'Gold',
#   'AGIL': 'Information Technology Services',
#   'AGIO': 'Biotechnology',
#   'AGL': 'Medical Care Facilities',
#   'AGLE': 'Biotechnology',
#   'AGM': 'Credit Services',
#   'AGMH': 'Computer Hardware',
#   'AGNC': 'REIT—Mortgage',
#   'AGNCL': 'REIT—Mortgage',
#   'AGNCM': 'REIT—Mortgage',
#   'AGNCN': 'REIT—Mortgage',
#   'AGNCO': 'REIT—Mortgage',
#   'AGNCP': 'REIT—Mortgage',
#   'AGO': 'Insurance—Specialty',
#   'AGR': 'Utilities—Regulated Electric',
#   'AGRI': 'Farm Products',
#   'AGRIW': 'Farm Products',
#   'AGRO': 'Farm Products',
#   'AGRX': 'Drug Manufacturers—Specialty & Generic',
#   'AGS': 'Gambling',
#   'AGTI': 'Health Information Services',
#   'AGX': 'Engineering & Construction',
#   'AGYS': 'Software—Application',
#   'AHCO': 'Medical Devices',
#   'AHG': 'Medical Distribution',
#   'AHH': 'REIT—Diversified',
#   'AHI': 'Software—Application',
#   'AHRN': 'Shell Companies',
#   'AHRNU': 'Shell Companies',
#   'AHT': 'REIT—Hotel & Motel',
#   'AI': 'Software—Application',
#   'AIB': 'Shell Companies',
#   'AIBBU': 'Shell Companies',
#   'AIF': 'Asset Management',
#   'AIG': 'Insurance—Diversified',
#   'AIH': 'Medical Care Facilities',
#   'AIHS': 'Credit Services',
#   'AIM': 'Biotechnology',
#   'AIMD': 'Medical Devices',
#   'AIN': 'Textile Manufacturing',
#   'AINC': 'Asset Management',
#   'AIP': 'Semiconductors',
#   'AIR': 'Aerospace & Defense',
#   'AIRC': 'REIT—Residential',
#   'AIRG': 'Communication Equipment',
#   'AIRI': 'Aerospace & Defense',
#   'AIRS': 'Medical Care Facilities',
#   'AIRT': 'Integrated Freight & Logistics',
#   'AIRTP': 'Integrated Freight & Logistics',
#   'AIT': 'Industrial Distribution',
#   'AIU': 'Education & Training Services',
#   'AIV': 'REIT—Residential',
#   'AIXI': 'Software—Application',
#   'AIZ': 'Insurance—Specialty',
#   'AJG': 'Insurance Brokers',
#   'AJRD': 'Aerospace & Defense',
#   'AJX': 'REIT—Mortgage',
#   'AKA': 'Internet Retail',
#   'AKAM': 'Software—Infrastructure',
#   'AKAN': 'Drug Manufacturers—Specialty & Generic',
#   'AKBA': 'Biotechnology',
#   'AKLI': 'Health Information Services',
#   'AKR': 'REIT—Retail',
#   'AKRO': 'Biotechnology',
#   'AKTS': 'Communication Equipment',
#   'AKTX': 'Biotechnology',
#   'AKU': 'Diagnostics & Research',
#   'AKYA': 'Medical Instruments & Supplies',
#   'AL': 'Rental & Leasing Services',
#   'ALAR': 'Software—Infrastructure',
#   'ALB': 'Specialty Chemicals',
#   'ALBT': 'Real Estate Services',
#   'ALC': 'Medical Instruments & Supplies',
#   'ALCC': 'Shell Companies',
#   'ALCO': 'Farm Products',
#   'ALCYU': 'Shell Companies',
#   'ALDX': 'Biotechnology',
#   'ALE': 'Utilities—Diversified',
#   'ALEC': 'Biotechnology',
#   'ALEX': 'REIT—Retail',
#   'ALG': 'Farm & Heavy Construction Machinery',
#   'ALGM': 'Semiconductors',
#   'ALGN': 'Medical Devices',
#   'ALGS': 'Biotechnology',
#   'ALGT': 'Airlines',
#   'ALHC': 'Healthcare Plans',
#   'ALIM': 'Drug Manufacturers—Specialty & Generic',
#   'ALIT': 'Software—Application',
#   'ALK': 'Airlines',
#   'ALKS': 'Drug Manufacturers—Specialty & Generic',
#   'ALKT': 'Software—Application',
#   'ALL': 'Insurance—Property & Casualty',
#   'ALLE': 'Security & Protection Services',
#   'ALLG': 'Auto Parts',
#   'ALLK': 'Biotechnology',
#   'ALLO': 'Biotechnology',
#   'ALLR': 'Biotechnology',
#   'ALLT': 'Software—Infrastructure',
#   'ALLY': 'Credit Services',
#   'ALNY': 'Biotechnology',
#   'ALOR': 'Shell Companies',
#   'ALORU': 'Shell Companies',
#   'ALOT': 'Computer Hardware',
#   'ALPA': 'Shell Companies',
#   'ALPAU': 'Shell Companies',
#   'ALPN': 'Biotechnology',
#   'ALPP': 'Conglomerates',
#   'ALPS': 'Oil & Gas E&P',
#   'ALRM': 'Software—Application',
#   'ALRN': 'Biotechnology',
#   'ALRS': 'Banks—Regional',
#   'ALSA': 'Shell Companies',
#   'ALSAU': 'Shell Companies',
#   'ALSN': 'Auto Parts',
#   'ALT': 'Biotechnology',
#   'ALTG': 'Rental & Leasing Services',
#   'ALTI': 'Asset Management',
#   'ALTIW': 'Asset Management',
#   'ALTO': 'Specialty Chemicals',
#   'ALTR': 'Software—Infrastructure',
#   'ALTU': 'Shell Companies',
#   'ALTUU': 'Shell Companies',
#   'ALV': 'Auto Parts',
#   'ALVO': 'Drug Manufacturers—Specialty & Generic',
#   'ALVR': 'Biotechnology',
#   'ALX': 'REIT—Retail',
#   'ALXO': 'Biotechnology',
#   'ALYA': 'Information Technology Services',
#   'ALZN': 'Biotechnology',
#   'AM': 'Oil & Gas Midstream',
#   'AMAL': 'Banks—Regional',
#   'AMAM': 'Biotechnology',
#   'AMAO': 'Shell Companies',
#   'AMAOU': 'Shell Companies',
#   'AMAT': 'Semiconductor Equipment & Materials',
#   'AMBA': 'Semiconductor Equipment & Materials',
#   'AMBC': 'Insurance—Specialty',
#   'AMBI': 'Waste Management',
#   'AMBO': 'Education & Training Services',
#   'AMBP': 'Packaging & Containers',
#   'AMC': 'Entertainment',
#   'AMCR': 'Packaging & Containers',
#   'AMCX': 'Entertainment',
#   'AMD': 'Semiconductors',
#   'AME': 'Specialty Industrial Machinery',
#   'AMED': 'Medical Care Facilities',
#   'AMEH': 'Medical Care Facilities',
#   'AMG': 'Asset Management',
#   'AMGN': 'Drug Manufacturers—General',
#   'AMH': 'REIT—Residential',
#   'AMK': 'Asset Management',
#   'AMKR': 'Semiconductors',
#   'AMLI': 'Other Industrial Metals & Mining',
#   'AMLX': 'Biotechnology',
#   'AMN': 'Medical Care Facilities',
#   'AMNB': 'Banks—Regional',
#   'AMOT': 'Electronic Components',
#   'AMP': 'Asset Management',
#   'AMPE': 'Biotechnology',
#   'AMPG': 'Communication Equipment',
#   'AMPH': 'Drug Manufacturers—Specialty & Generic',
#   'AMPL': 'Software—Application',
#   'AMPS': 'Utilities—Renewable',
#   'AMPX': 'Electrical Equipment & Parts',
#   'AMPY': 'Oil & Gas E&P',
#   'AMR': 'Coking Coal',
#   'AMRC': 'Engineering & Construction',
#   'AMRK': 'Capital Markets',
#   'AMRN': 'Drug Manufacturers—General',
#   'AMRS': 'Specialty Chemicals',
#   'AMRX': 'Drug Manufacturers—Specialty & Generic',
#   'AMS': 'Medical Care Facilities',
#   'AMSC': 'Specialty Industrial Machinery',
#   'AMSF': 'Insurance—Specialty',
#   'AMST': 'Software—Application',
#   'AMSWA': 'Software—Application',
#   'AMT': 'REIT—Specialty',
#   'AMTB': 'Banks—Regional',
#   'AMTD': 'Asset Management',
#   'AMTI': 'Biotechnology',
#   'AMTX': 'Oil & Gas Refining & Marketing',
#   'AMWD': 'Furnishings, Fixtures & Appliances',
#   'AMWL': 'Health Information Services',
#   'AMX': 'Telecom Services',
#   'AMZN': 'Internet Retail',
#   'AN': 'Auto & Truck Dealerships',
#   'ANAB': 'Biotechnology',
#   'ANDE': 'Food Distribution',
#   'ANEB': 'Biotechnology',
#   'ANET': 'Computer Hardware',
#   'ANF': 'Apparel Retail',
#   'ANGH': 'Entertainment',
#   'ANGI': 'Internet Content & Information',
#   'ANGO': 'Medical Instruments & Supplies',
#   'ANIK': 'Medical Devices',
#   'ANIP': 'Drug Manufacturers—Specialty & Generic',
#   'ANIX': 'Biotechnology',
#   'ANNX': 'Biotechnology',
#   'ANSS': 'Software—Application',
#   'ANTE': 'Telecom Services',
#   'ANTX': 'Biotechnology',
#   'ANVS': 'Biotechnology',
#   'ANY': 'Software—Application',
#   'ANZU': 'Shell Companies',
#   'ANZUU': 'Shell Companies',
#   'AOD': 'Asset Management',
#   'AOGO': 'Shell Companies',
#   'AOGOU': 'Shell Companies',
#   'AOMR': 'REIT—Mortgage',
#   'AON': 'Insurance Brokers',
#   'AORT': 'Medical Devices',
#   'AOS': 'Specialty Industrial Machinery',
#   'AOSL': 'Semiconductors',
#   'AOUT': 'Leisure',
#   'AP': 'Metal Fabrication',
#   'APA': 'Oil & Gas E&P',
#   'APAC': 'Shell Companies',
#   'APACU': 'Shell Companies',
#   'APAM': 'Asset Management',
#   'APCA': 'Shell Companies',
#   'APCX': 'Software—Infrastructure',
#   'APD': 'Specialty Chemicals',
#   'APDN': 'Diagnostics & Research',
#   'APE': 'Entertainment',
#   'APEI': 'Education & Training Services',
#   'APG': 'Engineering & Construction',
#   'APGB': 'Shell Companies',
#   'APGN': 'Biotechnology',
#   'APH': 'Electronic Components',
#   'API': 'Software—Application',
#   'APLD': 'Capital Markets',
#   'APLE': 'REIT—Hotel & Motel',
#   'APLM': 'Biotechnology',
#   'APLMW': 'Biotechnology',
#   'APLS': 'Biotechnology',
#   'APLT': 'Biotechnology',
#   'APM': 'Biotechnology',
#   'APMI': 'Shell Companies',
#   'APMIU': 'Shell Companies',
#   'APO': 'Asset Management',
#   'APOG': 'Building Products & Equipment',
#   'APP': 'Software—Application',
#   'APPF': 'Software—Application',
#   'APPH': 'Farm Products',
#   'APPN': 'Software—Infrastructure',
#   'APPS': 'Software—Application',
#   'APRE': 'Biotechnology',
#   'APRN': 'Internet Retail',
#   'APT': 'Building Products & Equipment',
#   'APTM': 'Shell Companies',
#   'APTMU': 'Shell Companies',
#   'APTO': 'Biotechnology',
#   'APTV': 'Auto Parts',
#   'APVO': 'Biotechnology',
#   'APWC': 'Electrical Equipment & Parts',
#   'APXI': 'Shell Companies',
#   'APXIU': 'Shell Companies',
#   'APYX': 'Medical Devices',
#   'AQB': 'Farm Products',
#   'AQMS': 'Waste Management',
#   'AQN': 'Utilities—Renewable',
#   'AQNU': 'Utilities—Renewable',
#   'AQST': 'Drug Manufacturers—Specialty & Generic',
#   'AQU': 'Shell Companies',
#   'AQUNU': 'Shell Companies',
#   'AR': 'Oil & Gas E&P',
#   'ARAV': 'Biotechnology',
#   'ARAY': 'Medical Devices',
#   'ARBB': 'Information Technology Services',
#   'ARBE': 'Software—Infrastructure',
#   'ARBEW': 'Software—Infrastructure',
#   'ARBG': 'Shell Companies',
#   'ARBGU': 'Shell Companies',
#   'ARBK': 'Capital Markets',
#   'ARC': 'Specialty Business Services',
#   'ARCB': 'Trucking',
#   'ARCC': 'Asset Management',
#   'ARCE': 'Education & Training Services',
#   'ARCH': 'Coking Coal',
#   'ARCO': 'Restaurants',
#   'ARCT': 'Biotechnology',
#   'ARDC': 'Asset Management',
#   'ARDS': 'Biotechnology',
#   'ARDX': 'Biotechnology',
#   'ARE': 'REIT—Office',
#   'AREB': 'Footwear & Accessories',
#   'AREC': 'Coking Coal',
#   'AREN': 'Internet Content & Information',
#   'ARES': 'Asset Management',
#   'ARGO': 'Insurance—Property & Casualty',
#   'ARGX': 'Biotechnology',
#   'ARHS': 'Home Improvement Retail',
#   'ARI': 'REIT—Mortgage',
#   'ARIS': 'Utilities—Regulated Water',
#   'ARIZ': 'Shell Companies',
#   'ARIZU': 'Shell Companies',
#   'ARKO': 'Specialty Retail',
#   'ARKOW': 'Specialty Retail',
#   'ARKR': 'Restaurants',
#   'ARL': 'Real Estate—Development',
#   'ARLO': 'Building Products & Equipment',
#   'ARLP': 'Thermal Coal',
#   'ARMK': 'Specialty Business Services',
#   'ARMP': 'Biotechnology',
#   'ARNC': 'Metal Fabrication',
#   'AROC': 'Oil & Gas Equipment & Services',
#   'AROW': 'Banks—Regional',
#   'ARQQ': 'Software—Infrastructure',
#   'ARQT': 'Biotechnology',
#   'ARR': 'REIT—Mortgage',
#   'ARRW': 'Shell Companies',
#   'ARRWU': 'Shell Companies',
#   'ARRY': 'Solar',
#   'ARTE': 'Shell Companies',
#   'ARTEU': 'Shell Companies',
#   'ARTL': 'Biotechnology',
#   'ARTNA': 'Utilities—Regulated Water',
#   'ARTW': 'Farm & Heavy Construction Machinery',
#   'ARVL': 'Auto Manufacturers',
#   'ARVN': 'Biotechnology',
#   'ARW': 'Electronics & Computer Distribution',
#   'ARWR': 'Biotechnology',
#   'ARYD': 'Shell Companies',
#   'ARYE': 'Shell Companies',
#   'ASA': 'Asset Management',
#   'ASAI': 'Grocery Stores',
#   'ASAN': 'Software—Application',
#   'ASB': 'Banks—Regional',
#   'ASC': 'Marine Shipping',
#   'ASCA': 'Shell Companies',
#   'ASCAU': 'Shell Companies',
#   'ASCB': 'Shell Companies',
#   'ASCBU': 'Shell Companies',
#   'ASG': 'Asset Management',
#   'ASGN': 'Information Technology Services',
#   'ASH': 'Specialty Chemicals',
#   'ASIX': 'Chemicals',
#   'ASLE': 'Airports & Air Services',
#   'ASLN': 'Biotechnology',
#   'ASM': 'Other Precious Metals & Mining',
#   'ASMB': 'Biotechnology',
#   'ASML': 'Semiconductor Equipment & Materials',
#   'ASND': 'Biotechnology',
#   'ASNS': 'Communication Equipment',
#   'ASO': 'Specialty Retail',
#   'ASPA': 'Shell Companies',
#   'ASPAU': 'Shell Companies',
#   'ASPI': 'Chemicals',
#   'ASPN': 'Building Products & Equipment',
#   'ASPS': 'Real Estate Services',
#   'ASR': 'Airports & Air Services',
#   'ASRT': 'Drug Manufacturers—Specialty & Generic',
#   'ASRV': 'Banks—Regional',
#   'ASST': 'Internet Content & Information',
#   'ASTC': 'Aerospace & Defense',
#   'ASTE': 'Farm & Heavy Construction Machinery',
#   'ASTI': 'Solar',
#   'ASTL': 'Steel',
#   'ASTR': 'Aerospace & Defense',
#   'ASTS': 'Communication Equipment',
#   'ASUR': 'Software—Application',
#   'ASX': 'Semiconductors',
#   'ASXC': 'Medical Devices',
#   'ASYS': 'Semiconductor Equipment & Materials',
#   'ATAI': 'Biotechnology',
#   'ATAK': 'Shell Companies',
#   'ATAKU': 'Shell Companies',
#   'ATAQ': 'Shell Companies',
#   'ATAT': 'Lodging',
#   'ATEC': 'Medical Devices',
#   'ATEK': 'Shell Companies',
#   'ATEN': 'Software—Infrastructure',
#   'ATER': 'Furnishings, Fixtures & Appliances',
#   'ATEX': 'Telecom Services',
#   'ATGE': 'Education & Training Services',
#   'ATHA': 'Biotechnology',
#   'ATHE': 'Biotechnology',
#   'ATHM': 'Internet Content & Information',
#   'ATHX': 'Biotechnology',
#   'ATI': 'Metal Fabrication',
#   'ATIF': 'Capital Markets',
#   'ATIP': 'Medical Care Facilities',
#   'ATKR': 'Electrical Equipment & Parts',
#   'ATLC': 'Credit Services',
#   'ATLCP': 'Credit Services',
#   'ATLO': 'Banks—Regional',
#   'ATLX': 'Other Precious Metals & Mining',
#   'ATMC': 'Shell Companies',
#   'ATMCU': 'Shell Companies',
#   'ATMU': 'Pollution & Treatment Controls',
#   'ATMV': 'Shell Companies',
#   'ATMVU': 'Shell Companies',
#   'ATNF': 'Biotechnology',
#   'ATNI': 'Telecom Services',
#   'ATNM': 'Biotechnology',
#   'ATO': 'Utilities—Regulated Gas',
#   'ATOM': 'Semiconductor Equipment & Materials',
#   'ATOS': 'Biotechnology',
#   'ATR': 'Medical Instruments & Supplies',
#   'ATRA': 'Biotechnology',
#   'ATRC': 'Medical Instruments & Supplies',
#   'ATRI': 'Medical Instruments & Supplies',
#   'ATRO': 'Aerospace & Defense',
#   'ATS': 'Specialty Industrial Machinery',
#   'ATSG': 'Airlines',
#   'ATTO': 'Specialty Business Services',
#   'ATUS': 'Telecom Services',
#   'ATVI': 'Electronic Gaming & Multimedia',
#   'ATXG': 'Integrated Freight & Logistics',
#   'ATXI': 'Biotechnology',
#   'ATXS': 'Biotechnology',
#   'AU': 'Gold',
#   'AUB': 'Banks—Regional',
#   'AUBN': 'Banks—Regional',
#   'AUDC': 'Communication Equipment',
#   'AUGX': 'Health Information Services',
#   'AUID': 'Software—Infrastructure',
#   'AULT': 'Aerospace & Defense',
#   'AUMN': 'Other Precious Metals & Mining',
#   'AUPH': 'Biotechnology',
#   'AUR': 'Information Technology Services',
#   'AURA': 'Biotechnology',
#   'AURC': 'Shell Companies',
#   'AURCU': 'Shell Companies',
#   'AUST': 'Gold',
#   'AUTL': 'Biotechnology',
#   'AUUD': 'Software—Application',
#   'AUVI': 'Furnishings, Fixtures & Appliances',
#   'AUVIP': 'Furnishings, Fixtures & Appliances',
#   'AVA': 'Utilities—Diversified',
#   'AVAC': 'Shell Companies',
#   'AVACU': 'Shell Companies',
#   'AVAH': 'Medical Care Facilities',
#   'AVAL': 'Banks—Regional',
#   'AVAV': 'Aerospace & Defense',
#   'AVB': 'REIT—Residential',
#   'AVD': 'Agricultural Inputs',
#   'AVDL': 'Drug Manufacturers—Specialty & Generic',
#   'AVDX': 'Software—Infrastructure',
#   'AVGO': 'Semiconductors',
#   'AVGR': 'Medical Instruments & Supplies',
#   'AVHI': 'Shell Companies',
#   'AVHIU': 'Shell Companies',
#   'AVID': 'Software—Application',
#   'AVIR': 'Biotechnology',
#   'AVK': 'Asset Management',
#   'AVNS': 'Medical Devices',
#   'AVNT': 'Specialty Chemicals',
#   'AVNW': 'Communication Equipment',
#   'AVO': 'Food Distribution',
#   'AVPT': 'Software—Infrastructure',
#   'AVRO': 'Biotechnology',
#   'AVT': 'Electronics & Computer Distribution',
#   'AVTA': 'Asset Management',
#   'AVTE': 'Biotechnology',
#   'AVTR': 'Specialty Chemicals',
#   'AVTX': 'Biotechnology',
#   'AVXL': 'Biotechnology',
#   'AVY': 'Packaging & Containers',
#   'AWF': 'Asset Management',
#   'AWH': 'Diagnostics & Research',
#   'AWI': 'Building Products & Equipment',
#   'AWIN': 'Scientific & Technical Instruments',
#   'AWINW': 'Scientific & Technical Instruments',
#   'AWK': 'Utilities—Regulated Water',
#   'AWP': 'Asset Management',
#   'AWR': 'Utilities—Regulated Water',
#   'AWRE': 'Software—Application',
#   'AWX': 'Waste Management',
#   'AX': 'Banks—Regional',
#   'AXDX': 'Medical Devices',
#   'AXGN': 'Medical Devices',
#   'AXL': 'Auto Parts',
#   'AXLA': 'Biotechnology',
#   'AXNX': 'Medical Devices',
#   'AXON': 'Aerospace & Defense',
#   'AXP': 'Credit Services',
#   'AXR': 'Real Estate—Development',
#   'AXS': 'Insurance—Specialty',
#   'AXSM': 'Biotechnology',
#   'AXTA': 'Specialty Chemicals',
#   'AXTI': 'Semiconductor Equipment & Materials',
#   'AY': 'Utilities—Renewable',
#   'AYI': 'Electrical Equipment & Parts',
#   'AYRO': 'Auto Manufacturers',
#   'AYTU': 'Drug Manufacturers—Specialty & Generic',
#   'AYX': 'Software—Application',
#   'AZ': 'Aerospace & Defense',
#   'AZEK': 'Building Products & Equipment',
#   'AZN': 'Drug Manufacturers—General',
#   'AZO': 'Specialty Retail',
#   'AZPN': 'Software—Application',
#   'AZRE': 'Utilities—Renewable',
#   'AZTA': 'Medical Instruments & Supplies',
#   'AZUL': 'Airlines',
#   'AZYO': 'Medical Devices',
#   'AZZ': 'Specialty Business Services',
#   'B': 'Specialty Industrial Machinery',
#   'BA': 'Aerospace & Defense',
#   'BABA': 'Internet Retail',
#   'BAC': 'Banks—Diversified',
#   'BACA': 'Shell Companies',
#   'BACK': 'Medical Care Facilities',
#   'BAER': 'Security & Protection Services',
#   'BAFN': 'Banks—Regional',
#   'BAH': 'Consulting Services',
#   'BAK': 'Chemicals',
#   'BALL': 'Packaging & Containers',
#   'BALY': 'Resorts & Casinos',
#   'BAM': 'Asset Management',
#   'BANC': 'Banks—Regional',
#   'BAND': 'Software—Infrastructure',
#   'BANF': 'Banks—Regional',
#   'BANL': 'Oil & Gas Midstream',
#   'BANR': 'Banks—Regional',
#   'BANX': 'Asset Management',
#   'BAOS': 'Advertising Agencies',
#   'BAP': 'Banks—Regional',
#   'BARK': 'Specialty Retail',
#   'BASE': 'Software—Infrastructure',
#   'BATL': 'Oil & Gas E&P',
#   'BATRA': 'Entertainment',
#   'BATRK': 'Entertainment',
#   'BAX': 'Medical Instruments & Supplies',
#   'BBAI': 'Information Technology Services',
#   'BBAR': 'Banks—Regional',
#   'BBCP': 'Engineering & Construction',
#   'BBD': 'Banks—Regional',
#   'BBDC': 'Credit Services',
#   'BBDO': 'Banks—Regional',
#   'BBGI': 'Broadcasting',
#   'BBIG': 'Leisure',
#   'BBIO': 'Biotechnology',
#   'BBLG': 'Medical Devices',
#   'BBLN': 'Health Information Services',
#   'BBN': 'Asset Management',
#   'BBSI': 'Staffing & Employment Services',
#   'BBU': 'Conglomerates',
#   'BBUC': 'Asset Management',
#   'BBVA': 'Banks—Diversified',
#   'BBW': 'Specialty Retail',
#   'BBWI': 'Specialty Retail',
#   'BBY': 'Specialty Retail',
#   'BC': 'Recreational Vehicles',
#   'BCAB': 'Biotechnology',
#   'BCAL': 'Banks—Regional',
#   'BCAN': 'Software—Infrastructure',
#   'BCBP': 'Banks—Regional',
#   'BCC': 'Building Materials',
#   'BCDA': 'Biotechnology',
#   'BCE': 'Telecom Services',
#   'BCEL': 'Biotechnology',
#   'BCH': 'Banks—Regional',
#   'BCLI': 'Biotechnology',
#   'BCML': 'Banks—Regional',
#   'BCO': 'Security & Protection Services',
#   'BCOV': 'Software—Application',
#   'BCOW': 'Banks—Regional',
#   'BCPC': 'Specialty Chemicals',
#   'BCRX': 'Biotechnology',
#   'BCS': 'Banks—Diversified',
#   'BCSA': 'Shell Companies',
#   'BCSAU': 'Shell Companies',
#   'BCSAW': 'Shell Companies',
#   'BCSF': 'Asset Management',
#   'BCTX': 'Biotechnology',
#   'BCV': 'Asset Management',
#   'BCX': 'Asset Management',
#   'BCYC': 'Biotechnology',
#   'BDC': 'Communication Equipment',
#   'BDJ': 'Asset Management',
#   'BDL': 'Restaurants',
#   'BDN': 'REIT—Office',
#   'BDRX': 'Biotechnology',
#   'BDSX': 'Diagnostics & Research',
#   'BDTX': 'Biotechnology',
#   'BDX': 'Medical Instruments & Supplies',
#   'BE': 'Electrical Equipment & Parts',
#   'BEAM': 'Biotechnology',
#   'BEAT': 'Health Information Services',
#   'BEATW': 'Health Information Services',
#   'BECN': 'Industrial Distribution',
#   'BEDU': 'Education & Training Services',
#   'BEEM': 'Solar',
#   'BEKE': 'Real Estate Services',
#   'BELFA': 'Electronic Components',
#   'BELFB': 'Electronic Components',
#   'BEN': 'Asset Management',
#   'BEP': 'Utilities—Renewable',
#   'BEPC': 'Utilities—Renewable',
#   'BERY': 'Packaging & Containers',
#   'BEST': 'Trucking',
#   'BFAC': 'Shell Companies',
#   'BFAM': 'Personal Services',
#   'BFC': 'Banks—Regional',
#   'BFH': 'Credit Services',
#   'BFI': 'Restaurants',
#   'BFIN': 'Banks—Regional',
#   'BFK': 'Asset Management',
#   'BFLY': 'Medical Devices',
#   'BFRG': 'Health Information Services',
#   'BFRGW': 'Health Information Services',
#   'BFRI': 'Drug Manufacturers—Specialty & Generic',
#   'BFS': 'REIT—Retail',
#   'BFST': 'Banks—Regional',
#   'BFZ': 'Asset Management',
#   'BG': 'Farm Products',
#   'BGB': 'Asset Management',
#   'BGCP': 'Capital Markets',
#   'BGFV': 'Specialty Retail',
#   'BGH': 'Asset Management',
#   'BGI': 'Luxury Goods',
#   'BGNE': 'Biotechnology',
#   'BGR': 'Asset Management',
#   'BGRY': 'Specialty Industrial Machinery',
#   'BGS': 'Packaged Foods',
#   'BGSF': 'Staffing & Employment Services',
#   'BGT': 'Asset Management',
#   'BGX': 'Asset Management',
#   'BGXX': 'Drug Manufacturers—Specialty & Generic',
#   'BGY': 'Asset Management',
#   'BH': 'Restaurants',
#   'BHAC': 'Shell Companies',
#   'BHACU': 'Shell Companies',
#   'BHAT': 'Electronic Gaming & Multimedia',
#   'BHB': 'Banks—Regional',
#   'BHC': 'Drug Manufacturers—Specialty & Generic',
#   'BHE': 'Electronic Components',
#   'BHF': 'Insurance—Life',
#   'BHFAM': 'Insurance—Life',
#   'BHFAN': 'Insurance—Life',
#   'BHFAO': 'Insurance—Life',
#   'BHFAP': 'Insurance—Life',
#   'BHG': 'Healthcare Plans',
#   'BHIL': 'Agricultural Inputs',
#   'BHK': 'Asset Management',
#   'BHLB': 'Banks—Regional',
#   'BHM': 'REIT—Residential',
#   'BHP': 'Other Industrial Metals & Mining',
#   'BHR': 'REIT—Hotel & Motel',
#   'BHRB': 'Banks—Regional',
#   'BHV': 'Asset Management',
#   'BHVN': 'Biotechnology',
#   'BIAF': 'Diagnostics & Research',
#   'BIDU': 'Internet Content & Information',
#   'BIG': 'Discount Stores',
#   'BIGC': 'Software—Application',
#   'BIGZ': 'Asset Management',
#   'BIIB': 'Drug Manufacturers—General',
#   'BILI': 'Electronic Gaming & Multimedia',
#   'BILL': 'Software—Application',
#   'BIMI': 'Pharmaceutical Retailers',
#   'BIO': 'Medical Devices',
#   'BIOC': 'Diagnostics & Research',
#   'BIOL': 'Medical Devices',
#   'BIOR': 'Biotechnology',
#   'BIOS': 'Shell Companies',
#   'BIOSU': 'Shell Companies',
#   'BIOX': 'Agricultural Inputs',
#   'BIP': 'Utilities—Diversified',
#   'BIPC': 'Utilities—Regulated Gas',
#   'BIRD': 'Apparel Retail',
#   'BIT': 'Asset Management',
#   'BITE': 'Shell Companies',
#   'BITF': 'Capital Markets',
#   'BIVI': 'Biotechnology',
#   'BJ': 'Discount Stores',
#   'BJDX': 'Medical Devices',
#   'BJRI': 'Restaurants',
#   'BK': 'Asset Management',
#   'BKCC': 'Asset Management',
#   'BKD': 'Medical Care Facilities',
#   'BKE': 'Apparel Retail',
#   'BKH': 'Utilities—Diversified',
#   'BKI': 'Software—Application',
#   'BKKT': 'Software—Infrastructure',
#   'BKN': 'Asset Management',
#   'BKNG': 'Travel Services',
#   'BKR': 'Oil & Gas Equipment & Services',
#   'BKSC': 'Banks—Regional',
#   'BKSY': 'Scientific & Technical Instruments',
#   'BKT': 'Asset Management',
#   'BKTI': 'Communication Equipment',
#   'BKU': 'Banks—Regional',
#   'BKYI': 'Security & Protection Services',
#   'BL': 'Software—Application',
#   'BLAC': 'Shell Companies',
#   'BLACU': 'Shell Companies',
#   'BLACW': 'Shell Companies',
#   'BLBD': 'Auto Manufacturers',
#   'BLBX': 'Software—Application',
#   'BLCO': 'Medical Instruments & Supplies',
#   'BLD': 'Engineering & Construction',
#   'BLDE': 'Airports & Air Services',
#   'BLDP': 'Specialty Industrial Machinery',
#   'BLDR': 'Building Products & Equipment',
#   'BLE': 'Asset Management',
#   'BLEU': 'Shell Companies',
#   'BLEUU': 'Shell Companies',
#   'BLFS': 'Medical Instruments & Supplies',
#   'BLFY': 'Banks—Regional',
#   'BLIN': 'Software—Infrastructure',
#   'BLK': 'Asset Management',
#   'BLKB': 'Software—Application',
#   'BLMN': 'Restaurants',
#   'BLND': 'Software—Application',
#   'BLNG': 'Shell Companies',
#   'BLNGU': 'Shell Companies',
#   'BLNK': 'Engineering & Construction',
#   'BLPH': 'Biotechnology',
#   'BLRX': 'Biotechnology',
#   'BLTE': 'Biotechnology',
#   'BLU': 'Biotechnology',
#   'BLUA': 'Shell Companies',
#   'BLUE': 'Biotechnology',
#   'BLW': 'Asset Management',
#   'BLX': 'Banks—Regional',
#   'BLZE': 'Software—Infrastructure',
#   'BMA': 'Banks—Regional',
#   'BMAC': 'Shell Companies',
#   'BMBL': 'Software—Application',
#   'BME': 'Asset Management',
#   'BMEA': 'Biotechnology',
#   'BMI': 'Scientific & Technical Instruments',
#   'BMN': 'Asset Management',
#   'BMR': 'Software—Application',
#   'BMRA': 'Medical Devices',
#   'BMRC': 'Banks—Regional',
#   'BMRN': 'Biotechnology',
#   'BMTX': 'Software—Application',
#   'BMY': 'Drug Manufacturers—General',
#   'BN': 'Asset Management',
#   'BNED': 'Specialty Retail',
#   'BNGO': 'Medical Instruments & Supplies',
#   'BNIX': 'Shell Companies',
#   'BNL': 'REIT—Diversified',
#   'BNMV': 'Oil & Gas Integrated',
#   'BNOX': 'Biotechnology',
#   'BNR': 'Diagnostics & Research',
#   'BNRE': 'Insurance—Reinsurance',
#   'BNRG': 'Utilities—Renewable',
#   'BNS': 'Banks—Diversified',
#   'BNSO': 'Scientific & Technical Instruments',
#   'BNTC': 'Biotechnology',
#   'BNTX': 'Biotechnology',
#   'BNY': 'Asset Management',
#   'BOAC': 'Shell Companies',
#   'BOC': 'Advertising Agencies',
#   'BOCN': 'Shell Companies',
#   'BOCNU': 'Shell Companies',
#   'BODY': 'Internet Content & Information',
#   'BOE': 'Asset Management',
#   'BOH': 'Banks—Regional',
#   'BOKF': 'Banks—Regional',
#   'BOLT': 'Biotechnology',
#   'BON': 'Packaged Foods',
#   'BOOM': 'Oil & Gas Equipment & Services',
#   'BOOT': 'Apparel Retail',
#   'BORR': 'Oil & Gas Drilling',
#   'BOSC': 'Communication Equipment',
#   'BOTJ': 'Banks—Regional',
#   'BOWL': 'Leisure',
#   'BOX': 'Software—Infrastructure',
#   'BOXL': 'Communication Equipment',
#   'BP': 'Oil & Gas Integrated',
#   'BPMC': 'Biotechnology',
#   'BPOP': 'Banks—Regional',
#   'BPRN': 'Banks—Regional',
#   'BPT': 'Oil & Gas Midstream',
#   'BPTH': 'Biotechnology',
#   'BPTS': 'Biotechnology',
#   'BPYPN': 'Real Estate Services',
#   'BPYPO': 'Real Estate Services',
#   'BPYPP': 'Real Estate Services',
#   'BQ': 'Specialty Retail',
#   'BR': 'Information Technology Services',
#   'BRAC': 'Shell Companies',
#   'BRACU': 'Shell Companies',
#   'BRAG': 'Electronic Gaming & Multimedia',
#   'BRBR': 'Packaged Foods',
#   'BRBS': 'Banks—Regional',
#   'BRC': 'Security & Protection Services',
#   'BRCC': 'Packaged Foods',
#   'BRD': 'Shell Companies',
#   'BRDG': 'Asset Management',
#   'BRDS': 'Rental & Leasing Services',
#   'BREA': 'Entertainment',
#   'BREZ': 'Shell Companies',
#   'BRFH': 'Beverages—Non-Alcoholic',
#   'BRFS': 'Packaged Foods',
#   'BRID': 'Packaged Foods',
#   'BRKH': 'Shell Companies',
#   'BRKHU': 'Shell Companies',
#   'BRKL': 'Banks—Regional',
#   'BRKR': 'Medical Devices',
#   'BRLI': 'Shell Companies',
#   'BRLIU': 'Shell Companies',
#   'BRLT': 'Luxury Goods',
#   'BRN': 'Oil & Gas E&P',
#   'BRO': 'Insurance Brokers',
#   'BROG': 'Oil & Gas Midstream',
#   'BROS': 'Restaurants',
#   'BRP': 'Insurance Brokers',
#   'BRQS': 'Software—Application',
#   'BRSH': 'Household & Personal Products',
#   'BRSP': 'REIT—Diversified',
#   'BRT': 'REIT—Residential',
#   'BRTX': 'Biotechnology',
#   'BRW': 'Asset Management',
#   'BRX': 'REIT—Retail',
#   'BRY': 'Oil & Gas E&P',
#   'BRZE': 'Software—Application',
#   'BSAC': 'Banks—Regional',
#   'BSAQ': 'Shell Companies',
#   'BSBK': 'Banks—Regional',
#   'BSBR': 'Banks—Regional',
#   'BSET': 'Furnishings, Fixtures & Appliances',
#   'BSFC': 'Packaged Foods',
#   'BSGM': 'Medical Devices',
#   'BSIG': 'Asset Management',
#   'BSL': 'Asset Management',
#   'BSM': 'Oil & Gas E&P',
#   'BSQR': 'Software—Application',
#   'BSRR': 'Banks—Regional',
#   'BST': 'Asset Management',
#   'BSTZ': 'Asset Management',
#   'BSVN': 'Banks—Regional',
#   'BSX': 'Medical Devices',
#   ...}}

# %%
import pandas as pd
import pickle
industries_dict = industries['industries']
df = pd.DataFrame(industries_dict.items(), columns=['symbol', 'industry'])

# %%
df
# Out:
#      symbol                                industry
# 0         A                  Diagnostics & Research
# 1        AA                                Aluminum
# 2       AAC                         Shell Companies
# 3      AACG           Education & Training Services
# 4      AACI                         Shell Companies
# ...     ...                                     ...
# 6736   ZVSA                           Biotechnology
# 6737    ZWS          Pollution & Treatment Controls
# 6738   ZYME                           Biotechnology
# 6739   ZYNE  Drug Manufacturers—Specialty & Generic
# 6740   ZYXI                    Medical Distribution
#
# [6741 rows x 2 columns]

# %%
sorted_df = df.sort_values("industry")

# %%
sorted_df
# Out:
#      symbol              industry
# 3971   MOBQ  Advertising Agencies
# 3201    IPG  Advertising Agencies
# 1588    CTV  Advertising Agencies
# 4513    OMC  Advertising Agencies
# 6516   WIMI  Advertising Agencies
# ...     ...                   ...
# 3640  LNZAW      Waste Management
# 3639   LNZA      Waste Management
# 2801   HCCI      Waste Management
# 3840    MEG      Waste Management
# 1636   CWST      Waste Management
#
# [6741 rows x 2 columns]

# %%
sorted_df.nunique()
# Out:
# symbol      6741
# industry     147
# dtype: int64

# %%
# !git add .
# !git commit -m "dataframe containing stocks symbols and corresponding industries"
# !git push origin main
# Out:
# [main 713009e] dataframe containing stocks symbols and corresponding industries
#  1 file changed, 88 insertions(+), 36 deletions(-)
#  rename Untitled.ipynb => df of industries .ipynb (96%)
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 44.09 KiB | 4.01 MiB/s, done.
# Total 7 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To github.com:Fetyukovitch/SMA.git
#    00781ce..713009e  main -> main
